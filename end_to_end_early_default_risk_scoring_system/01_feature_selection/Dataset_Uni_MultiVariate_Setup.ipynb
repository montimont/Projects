# %%
import pandas as pd

# %%
data = pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/Scorecard_Project/loan_data.csv')

# %% [markdown]
# # datasetForUnivariateVSExceptIV

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

# %%
def calculate_woe_iv(dataset, feature, target):
    lst = []
    for i in range(dataset[feature].nunique()):
        val = list(dataset[feature].unique())[i]
        lst.append({
            'Value': val,
            'All': dataset[dataset[feature] == val].count()[feature],
            'Good': dataset[(dataset[feature] == val) & (dataset[target] == 0)].count()[feature],
            'Bad': dataset[(dataset[feature] == val) & (dataset[target] == 1)].count()[feature]
        })

    dset = pd.DataFrame(lst)
    dset['Distr_Good'] = (dset['Good'] + 0.5) / dset['Good'].sum()
    dset['Distr_Bad'] = (dset['Bad'] + 0.5) / dset['Bad'].sum()
    dset['WoE'] = np.log(dset['Distr_Good']/ dset['Distr_Bad'])
    dset['IV'] = (dset['Distr_Good'] - dset['Distr_Bad']) * dset['WoE']
    iv = dset['IV'].sum()

    dset = dset.sort_values(by='WoE')

    return dset[['Value', 'All', 'Good', 'Bad', 'WoE']], iv

# %%
lstvar = ['person_education',
 'person_income',
 'person_emp_exp',
 'person_home_ownership',
 'loan_amnt',
 'loan_intent',
 'loan_int_rate',
 'loan_percent_income',
 'cb_person_cred_hist_length',
 'credit_score',
 'previous_loan_defaults_on_file',
 'loan_status']

# %%
combined = data[lstvar]

# %%
combined.head()
# Out:
#   person_education  person_income  person_emp_exp person_home_ownership  \
# 0           Master        71948.0               0                  RENT
# 1      High School        12282.0               0                   OWN
# 2      High School        12438.0               3              MORTGAGE
# 3         Bachelor        79753.0               0                  RENT
# 4           Master        66135.0               1                  RENT
#
#    loan_amnt loan_intent  loan_int_rate  loan_percent_income  \
# 0    35000.0    PERSONAL          16.02                 0.49
# 1     1000.0   EDUCATION          11.14                 0.08
# 2     5500.0     MEDICAL          12.87                 0.44
# 3    35000.0     MEDICAL          15.23                 0.44
# 4    35000.0     MEDICAL          14.27                 0.53
#
#    cb_person_cred_hist_length  credit_score previous_loan_defaults_on_file  \
# 0                         3.0           561                             No
# 1                         2.0           504                            Yes
# 2                         3.0           635                             No
# 3                         2.0           675                             No
# 4                         4.0           586                             No
#
#    loan_status
# 0            1
# 1            0
# 2            1
# 3            1
# 4            1

# %%
dataFiltered = combined

# %%
dataToAnalyze = dataFiltered

# %%
dataToAnalyze
# Out:
#       person_education  person_income  person_emp_exp person_home_ownership  \
# 0               Master        71948.0               0                  RENT
# 1          High School        12282.0               0                   OWN
# 2          High School        12438.0               3              MORTGAGE
# 3             Bachelor        79753.0               0                  RENT
# 4               Master        66135.0               1                  RENT
# ...                ...            ...             ...                   ...
# 44995        Associate        47971.0               6                  RENT
# 44996        Associate        65800.0              17                  RENT
# 44997        Associate        56942.0               7                  RENT
# 44998         Bachelor        33164.0               4                  RENT
# 44999      High School        51609.0               1                  RENT
#
#        loan_amnt        loan_intent  loan_int_rate  loan_percent_income  \
# 0        35000.0           PERSONAL          16.02                 0.49
# 1         1000.0          EDUCATION          11.14                 0.08
# 2         5500.0            MEDICAL          12.87                 0.44
# 3        35000.0            MEDICAL          15.23                 0.44
# 4        35000.0            MEDICAL          14.27                 0.53
# ...          ...                ...            ...                  ...
# 44995    15000.0            MEDICAL          15.66                 0.31
# 44996     9000.0    HOMEIMPROVEMENT          14.07                 0.14
# 44997     2771.0  DEBTCONSOLIDATION          10.02                 0.05
# 44998    12000.0          EDUCATION          13.23                 0.36
# 44999     6665.0  DEBTCONSOLIDATION          17.05                 0.13
#
#        cb_person_cred_hist_length  credit_score  \
# 0                             3.0           561
# 1                             2.0           504
# 2                             3.0           635
# 3                             2.0           675
# 4                             4.0           586
# ...                           ...           ...
# 44995                         3.0           645
# 44996                        11.0           621
# 44997                        10.0           668
# 44998                         6.0           604
# 44999                         3.0           628
#
#       previous_loan_defaults_on_file  loan_status
# 0                                 No            1
# 1                                Yes            0
# 2                                 No            1
# 3                                 No            1
# 4                                 No            1
# ...                              ...          ...
# 44995                             No            1
# 44996                             No            1
# 44997                             No            1
# 44998                             No            1
# 44999                             No            1
#
# [45000 rows x 12 columns]

# %%
dataToAnalyze = dataToAnalyze.fillna(-1)

# %%
dataToAnalyze.head()
# Out:
#   person_education  person_income  person_emp_exp person_home_ownership  \
# 0           Master        71948.0               0                  RENT
# 1      High School        12282.0               0                   OWN
# 2      High School        12438.0               3              MORTGAGE
# 3         Bachelor        79753.0               0                  RENT
# 4           Master        66135.0               1                  RENT
#
#    loan_amnt loan_intent  loan_int_rate  loan_percent_income  \
# 0    35000.0    PERSONAL          16.02                 0.49
# 1     1000.0   EDUCATION          11.14                 0.08
# 2     5500.0     MEDICAL          12.87                 0.44
# 3    35000.0     MEDICAL          15.23                 0.44
# 4    35000.0     MEDICAL          14.27                 0.53
#
#    cb_person_cred_hist_length  credit_score previous_loan_defaults_on_file  \
# 0                         3.0           561                             No
# 1                         2.0           504                            Yes
# 2                         3.0           635                             No
# 3                         2.0           675                             No
# 4                         4.0           586                             No
#
#    loan_status
# 0            1
# 1            0
# 2            1
# 3            1
# 4            1

# %%
dataToAnalyze.select_dtypes(include=['object'])
# Out:
#       person_education person_home_ownership        loan_intent  \
# 0               Master                  RENT           PERSONAL
# 1          High School                   OWN          EDUCATION
# 2          High School              MORTGAGE            MEDICAL
# 3             Bachelor                  RENT            MEDICAL
# 4               Master                  RENT            MEDICAL
# ...                ...                   ...                ...
# 44995        Associate                  RENT            MEDICAL
# 44996        Associate                  RENT    HOMEIMPROVEMENT
# 44997        Associate                  RENT  DEBTCONSOLIDATION
# 44998         Bachelor                  RENT          EDUCATION
# 44999      High School                  RENT  DEBTCONSOLIDATION
#
#       previous_loan_defaults_on_file
# 0                                 No
# 1                                Yes
# 2                                 No
# 3                                 No
# 4                                 No
# ...                              ...
# 44995                             No
# 44996                             No
# 44997                             No
# 44998                             No
# 44999                             No
#
# [45000 rows x 4 columns]

# %%
dictobject = dict(dataToAnalyze.select_dtypes(include=['object']).nunique())

# %%
dictobject
# Out:
# {'person_education': 5,
#  'person_home_ownership': 4,
#  'loan_intent': 6,
#  'previous_loan_defaults_on_file': 2}

# %%
lstobject = [k for (k,v) in dictobject.items() if v < 50]

# %%
lstobject
# Out:
# ['person_education',
#  'person_home_ownership',
#  'loan_intent',
#  'previous_loan_defaults_on_file']

# %%
lstToremove = [k for (k,v) in dictobject.items() if v >= 100]

# %%
lstToremove
# Out:
# []

# %%
dataToAnalyze.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_education                45000 non-null  object
#  1   person_income                   45000 non-null  float64
#  2   person_emp_exp                  45000 non-null  int64
#  3   person_home_ownership           45000 non-null  object
#  4   loan_amnt                       45000 non-null  float64
#  5   loan_intent                     45000 non-null  object
#  6   loan_int_rate                   45000 non-null  float64
#  7   loan_percent_income             45000 non-null  float64
#  8   cb_person_cred_hist_length      45000 non-null  float64
#  9   credit_score                    45000 non-null  int64
#  10  previous_loan_defaults_on_file  45000 non-null  object
#  11  loan_status                     45000 non-null  int64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 4.1+ MB

# %%
dataToAnalyze = dataToAnalyze.drop(columns = lstToremove)

# %%
lstobject = list(dataToAnalyze.select_dtypes(include=['object']).columns)

# %%
IVs = []
woe_mappings = []
features = []

# %%
for i in lstobject:
    try:
        woe, iv = calculate_woe_iv(dataToAnalyze, i, 'loan_status')
        woe_map = dict(zip(woe['Value'], woe['WoE']))

        dataToAnalyze.loc[:, i] = dataToAnalyze[i].map(woe_map)

        # Only append if everything above succeeded
        features.append(i)
        IVs.append(iv)
        woe_mappings.append(woe_map)

    except Exception as e:
        print(f"[SKIPPED] {i} due to error: {e}")

# %%
results = pd.DataFrame({
    'features': features,
    'iv': IVs,
    'woe_mappings': woe_mappings
})

# %%
results
# Out:
#                          features        iv  \
# 0                person_education  0.000261
# 1           person_home_ownership  0.426093
# 2                     loan_intent  0.119598
# 3  previous_loan_defaults_on_file  6.880708
#
#                                         woe_mappings
# 0  {'Doctorate': -0.03936107388058031, 'Bachelor'...
# 1  {'OTHER': -0.5659650156140816, 'RENT': -0.5172...
# 2  {'DEBTCONSOLIDATION': -0.4185584760733577, 'ME...
# 3  {'No': -1.0586863650016927, 'Yes': 9.477462530...

# %%
dataToAnalyze.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_education                45000 non-null  object
#  1   person_income                   45000 non-null  float64
#  2   person_emp_exp                  45000 non-null  int64
#  3   person_home_ownership           45000 non-null  object
#  4   loan_amnt                       45000 non-null  float64
#  5   loan_intent                     45000 non-null  object
#  6   loan_int_rate                   45000 non-null  float64
#  7   loan_percent_income             45000 non-null  float64
#  8   cb_person_cred_hist_length      45000 non-null  float64
#  9   credit_score                    45000 non-null  int64
#  10  previous_loan_defaults_on_file  45000 non-null  object
#  11  loan_status                     45000 non-null  int64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 4.1+ MB

# %%
dataToAnalyze[lstobject] = dataToAnalyze[lstobject].astype('float64')

# %%
dataToAnalyze.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_education                45000 non-null  float64
#  1   person_income                   45000 non-null  float64
#  2   person_emp_exp                  45000 non-null  int64
#  3   person_home_ownership           45000 non-null  float64
#  4   loan_amnt                       45000 non-null  float64
#  5   loan_intent                     45000 non-null  float64
#  6   loan_int_rate                   45000 non-null  float64
#  7   loan_percent_income             45000 non-null  float64
#  8   cb_person_cred_hist_length      45000 non-null  float64
#  9   credit_score                    45000 non-null  int64
#  10  previous_loan_defaults_on_file  45000 non-null  float64
#  11  loan_status                     45000 non-null  int64
# dtypes: float64(9), int64(3)
# memory usage: 4.1 MB

# %%
dataToAnalyze[lstobject]
# Out:
#        person_education  person_home_ownership  loan_intent  \
# 0              0.026579              -0.517244     0.124536
# 1             -0.005227               1.254184     0.335716
# 2             -0.005227               0.778283    -0.299453
# 3             -0.017498              -0.517244    -0.299453
# 4              0.026579              -0.517244    -0.299453
# ...                 ...                    ...          ...
# 44995          0.010909              -0.517244    -0.299453
# 44996          0.010909              -0.517244    -0.222661
# 44997          0.010909              -0.517244    -0.418558
# 44998         -0.017498              -0.517244     0.335716
# 44999         -0.005227              -0.517244    -0.418558
#
#        previous_loan_defaults_on_file
# 0                           -1.058686
# 1                            9.477463
# 2                           -1.058686
# 3                           -1.058686
# 4                           -1.058686
# ...                               ...
# 44995                       -1.058686
# 44996                       -1.058686
# 44997                       -1.058686
# 44998                       -1.058686
# 44999                       -1.058686
#
# [45000 rows x 4 columns]

# %%
dataToAnalyze[lstobject].nunique()
# Out:
# person_education                  5
# person_home_ownership             4
# loan_intent                       6
# previous_loan_defaults_on_file    2
# dtype: int64

# %%
dataToAnalyze[lstobject].isna().sum()
# Out:
# person_education                  0
# person_home_ownership             0
# loan_intent                       0
# previous_loan_defaults_on_file    0
# dtype: int64

# %%
dataToAnalyze[lstobject] = dataToAnalyze[lstobject].apply(lambda x: x*100)

# %%
dataToAnalyze[lstobject]
# Out:
#        person_education  person_home_ownership  loan_intent  \
# 0              2.657918             -51.724408    12.453608
# 1             -0.522740             125.418365    33.571609
# 2             -0.522740              77.828324   -29.945313
# 3             -1.749761             -51.724408   -29.945313
# 4              2.657918             -51.724408   -29.945313
# ...                 ...                    ...          ...
# 44995          1.090857             -51.724408   -29.945313
# 44996          1.090857             -51.724408   -22.266123
# 44997          1.090857             -51.724408   -41.855848
# 44998         -1.749761             -51.724408    33.571609
# 44999         -0.522740             -51.724408   -41.855848
#
#        previous_loan_defaults_on_file
# 0                         -105.868637
# 1                          947.746253
# 2                         -105.868637
# 3                         -105.868637
# 4                         -105.868637
# ...                               ...
# 44995                     -105.868637
# 44996                     -105.868637
# 44997                     -105.868637
# 44998                     -105.868637
# 44999                     -105.868637
#
# [45000 rows x 4 columns]

# %%
dataToAnalyze.to_csv('Internal_test_0_datasetForUnivariateVSExceptIV.csv')

# %%
results.to_csv('Internal_test_0_univariateVS_woe_mappings_iv.csv')

# %% [markdown]
# # datasetForMultivariateVSExceptIV

# %%
def calculate_woe_iv(dataset, feature, target):
    lst = []
    for i in range(dataset[feature].nunique()):
        val = list(dataset[feature].unique())[i]
        lst.append({
            'Value': val,
            'All': dataset[dataset[feature] == val].count()[feature],
            'Good': dataset[(dataset[feature] == val) & (dataset[target] == 0)].count()[feature],
            'Bad': dataset[(dataset[feature] == val) & (dataset[target] == 1)].count()[feature]
        })

    dset = pd.DataFrame(lst)
    dset['Distr_Good'] = (dset['Good'] + 0.5) / dset['Good'].sum()
    dset['Distr_Bad'] = (dset['Bad'] + 0.5) / dset['Bad'].sum()
    dset['WoE'] = np.log(dset['Distr_Good']/ dset['Distr_Bad'])
    dset['IV'] = (dset['Distr_Good'] - dset['Distr_Bad']) * dset['WoE']
    iv = dset['IV'].sum()

    dset = dset.sort_values(by='WoE')

    return dset[['Value', 'All', 'Good', 'Bad', 'WoE']], iv

# %%
lstvar = ['person_education',
 'person_income',
 'person_emp_exp',
 'person_home_ownership',
 'loan_amnt',
 'loan_intent',
 'loan_int_rate',
 'loan_percent_income',
 'cb_person_cred_hist_length',
 'credit_score',
 'previous_loan_defaults_on_file',
 'loan_status']

# %%
combined = data[lstvar]

# %%
combined.head()
# Out:
#   person_education  person_income  person_emp_exp person_home_ownership  \
# 0           Master        71948.0               0                  RENT
# 1      High School        12282.0               0                   OWN
# 2      High School        12438.0               3              MORTGAGE
# 3         Bachelor        79753.0               0                  RENT
# 4           Master        66135.0               1                  RENT
#
#    loan_amnt loan_intent  loan_int_rate  loan_percent_income  \
# 0    35000.0    PERSONAL          16.02                 0.49
# 1     1000.0   EDUCATION          11.14                 0.08
# 2     5500.0     MEDICAL          12.87                 0.44
# 3    35000.0     MEDICAL          15.23                 0.44
# 4    35000.0     MEDICAL          14.27                 0.53
#
#    cb_person_cred_hist_length  credit_score previous_loan_defaults_on_file  \
# 0                         3.0           561                             No
# 1                         2.0           504                            Yes
# 2                         3.0           635                             No
# 3                         2.0           675                             No
# 4                         4.0           586                             No
#
#    loan_status
# 0            1
# 1            0
# 2            1
# 3            1
# 4            1

# %%
dataFiltered = combined

# %%
dataToAnalyze = dataFiltered.iloc[:, :]

# %%
dataToAnalyze
# Out:
#       person_education  person_income  person_emp_exp person_home_ownership  \
# 0               Master        71948.0               0                  RENT
# 1          High School        12282.0               0                   OWN
# 2          High School        12438.0               3              MORTGAGE
# 3             Bachelor        79753.0               0                  RENT
# 4               Master        66135.0               1                  RENT
# ...                ...            ...             ...                   ...
# 44995        Associate        47971.0               6                  RENT
# 44996        Associate        65800.0              17                  RENT
# 44997        Associate        56942.0               7                  RENT
# 44998         Bachelor        33164.0               4                  RENT
# 44999      High School        51609.0               1                  RENT
#
#        loan_amnt        loan_intent  loan_int_rate  loan_percent_income  \
# 0        35000.0           PERSONAL          16.02                 0.49
# 1         1000.0          EDUCATION          11.14                 0.08
# 2         5500.0            MEDICAL          12.87                 0.44
# 3        35000.0            MEDICAL          15.23                 0.44
# 4        35000.0            MEDICAL          14.27                 0.53
# ...          ...                ...            ...                  ...
# 44995    15000.0            MEDICAL          15.66                 0.31
# 44996     9000.0    HOMEIMPROVEMENT          14.07                 0.14
# 44997     2771.0  DEBTCONSOLIDATION          10.02                 0.05
# 44998    12000.0          EDUCATION          13.23                 0.36
# 44999     6665.0  DEBTCONSOLIDATION          17.05                 0.13
#
#        cb_person_cred_hist_length  credit_score  \
# 0                             3.0           561
# 1                             2.0           504
# 2                             3.0           635
# 3                             2.0           675
# 4                             4.0           586
# ...                           ...           ...
# 44995                         3.0           645
# 44996                        11.0           621
# 44997                        10.0           668
# 44998                         6.0           604
# 44999                         3.0           628
#
#       previous_loan_defaults_on_file  loan_status
# 0                                 No            1
# 1                                Yes            0
# 2                                 No            1
# 3                                 No            1
# 4                                 No            1
# ...                              ...          ...
# 44995                             No            1
# 44996                             No            1
# 44997                             No            1
# 44998                             No            1
# 44999                             No            1
#
# [45000 rows x 12 columns]

# %%
dataToAnalyze = dataToAnalyze.fillna(-1)

# %%
dataToAnalyze.head()
# Out:
#   person_education  person_income  person_emp_exp person_home_ownership  \
# 0           Master        71948.0               0                  RENT
# 1      High School        12282.0               0                   OWN
# 2      High School        12438.0               3              MORTGAGE
# 3         Bachelor        79753.0               0                  RENT
# 4           Master        66135.0               1                  RENT
#
#    loan_amnt loan_intent  loan_int_rate  loan_percent_income  \
# 0    35000.0    PERSONAL          16.02                 0.49
# 1     1000.0   EDUCATION          11.14                 0.08
# 2     5500.0     MEDICAL          12.87                 0.44
# 3    35000.0     MEDICAL          15.23                 0.44
# 4    35000.0     MEDICAL          14.27                 0.53
#
#    cb_person_cred_hist_length  credit_score previous_loan_defaults_on_file  \
# 0                         3.0           561                             No
# 1                         2.0           504                            Yes
# 2                         3.0           635                             No
# 3                         2.0           675                             No
# 4                         4.0           586                             No
#
#    loan_status
# 0            1
# 1            0
# 2            1
# 3            1
# 4            1

# %%
dataToAnalyze.select_dtypes(include=['object'])
# Out:
#       person_education person_home_ownership        loan_intent  \
# 0               Master                  RENT           PERSONAL
# 1          High School                   OWN          EDUCATION
# 2          High School              MORTGAGE            MEDICAL
# 3             Bachelor                  RENT            MEDICAL
# 4               Master                  RENT            MEDICAL
# ...                ...                   ...                ...
# 44995        Associate                  RENT            MEDICAL
# 44996        Associate                  RENT    HOMEIMPROVEMENT
# 44997        Associate                  RENT  DEBTCONSOLIDATION
# 44998         Bachelor                  RENT          EDUCATION
# 44999      High School                  RENT  DEBTCONSOLIDATION
#
#       previous_loan_defaults_on_file
# 0                                 No
# 1                                Yes
# 2                                 No
# 3                                 No
# 4                                 No
# ...                              ...
# 44995                             No
# 44996                             No
# 44997                             No
# 44998                             No
# 44999                             No
#
# [45000 rows x 4 columns]

# %%
dictobject = dict(dataToAnalyze.select_dtypes(include=['object']).nunique())

# %%
dictobject
# Out:
# {'person_education': 5,
#  'person_home_ownership': 4,
#  'loan_intent': 6,
#  'previous_loan_defaults_on_file': 2}

# %%
lstobject = [k for (k,v) in dictobject.items() if v < 50]

# %%
lstobject
# Out:
# ['person_education',
#  'person_home_ownership',
#  'loan_intent',
#  'previous_loan_defaults_on_file']

# %%
lstToremove = [k for (k,v) in dictobject.items() if v >= 100]

# %%
lstToremove
# Out:
# []

# %%
lstobject
# Out:
# ['person_education',
#  'person_home_ownership',
#  'loan_intent',
#  'previous_loan_defaults_on_file']

# %%
dataToAnalyze.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_education                45000 non-null  object
#  1   person_income                   45000 non-null  float64
#  2   person_emp_exp                  45000 non-null  int64
#  3   person_home_ownership           45000 non-null  object
#  4   loan_amnt                       45000 non-null  float64
#  5   loan_intent                     45000 non-null  object
#  6   loan_int_rate                   45000 non-null  float64
#  7   loan_percent_income             45000 non-null  float64
#  8   cb_person_cred_hist_length      45000 non-null  float64
#  9   credit_score                    45000 non-null  int64
#  10  previous_loan_defaults_on_file  45000 non-null  object
#  11  loan_status                     45000 non-null  int64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 4.1+ MB

# %%
dataToAnalyze = dataToAnalyze.drop(columns = lstToremove)

# %%
lstobject = list(dataToAnalyze.select_dtypes(include=['object']).columns)

# %%
lstobject
# Out:
# ['person_education',
#  'person_home_ownership',
#  'loan_intent',
#  'previous_loan_defaults_on_file']

# %%
IVs = []
woe_mappings = []
features = []

# %%
for i in lstobject:
    try:
        woe, iv = calculate_woe_iv(dataToAnalyze, i, 'loan_status')
        woe_map = dict(zip(woe['Value'], woe['WoE']))

        dataToAnalyze.loc[:, i] = dataToAnalyze[i].map(woe_map)

        # Only append if everything above succeeded
        features.append(i)
        IVs.append(iv)
        woe_mappings.append(woe_map)

    except Exception as e:
        print(f"[SKIPPED] {i} due to error: {e}")

# %%
results = pd.DataFrame({
    'features': features,
    'iv': IVs,
    'woe_mappings': woe_mappings
})

# %%
results
# Out:
#                          features        iv  \
# 0                person_education  0.000261
# 1           person_home_ownership  0.426093
# 2                     loan_intent  0.119598
# 3  previous_loan_defaults_on_file  6.880708
#
#                                         woe_mappings
# 0  {'Doctorate': -0.03936107388058031, 'Bachelor'...
# 1  {'OTHER': -0.5659650156140816, 'RENT': -0.5172...
# 2  {'DEBTCONSOLIDATION': -0.4185584760733577, 'ME...
# 3  {'No': -1.0586863650016927, 'Yes': 9.477462530...

# %%
dataToAnalyze[lstobject] = dataToAnalyze[lstobject].astype('float64')

# %%
dataToAnalyze[lstobject]
# Out:
#        person_education  person_home_ownership  loan_intent  \
# 0              0.026579              -0.517244     0.124536
# 1             -0.005227               1.254184     0.335716
# 2             -0.005227               0.778283    -0.299453
# 3             -0.017498              -0.517244    -0.299453
# 4              0.026579              -0.517244    -0.299453
# ...                 ...                    ...          ...
# 44995          0.010909              -0.517244    -0.299453
# 44996          0.010909              -0.517244    -0.222661
# 44997          0.010909              -0.517244    -0.418558
# 44998         -0.017498              -0.517244     0.335716
# 44999         -0.005227              -0.517244    -0.418558
#
#        previous_loan_defaults_on_file
# 0                           -1.058686
# 1                            9.477463
# 2                           -1.058686
# 3                           -1.058686
# 4                           -1.058686
# ...                               ...
# 44995                       -1.058686
# 44996                       -1.058686
# 44997                       -1.058686
# 44998                       -1.058686
# 44999                       -1.058686
#
# [45000 rows x 4 columns]

# %%
dataToAnalyze[lstobject].nunique()
# Out:
# person_education                  5
# person_home_ownership             4
# loan_intent                       6
# previous_loan_defaults_on_file    2
# dtype: int64

# %%
dataToAnalyze[lstobject].isna().sum()
# Out:
# person_education                  0
# person_home_ownership             0
# loan_intent                       0
# previous_loan_defaults_on_file    0
# dtype: int64

# %%
dataToAnalyze[lstobject] = dataToAnalyze[lstobject].apply(lambda x: x*100)

# %%
dataToAnalyze[lstobject]
# Out:
#        person_education  person_home_ownership  loan_intent  \
# 0              2.657918             -51.724408    12.453608
# 1             -0.522740             125.418365    33.571609
# 2             -0.522740              77.828324   -29.945313
# 3             -1.749761             -51.724408   -29.945313
# 4              2.657918             -51.724408   -29.945313
# ...                 ...                    ...          ...
# 44995          1.090857             -51.724408   -29.945313
# 44996          1.090857             -51.724408   -22.266123
# 44997          1.090857             -51.724408   -41.855848
# 44998         -1.749761             -51.724408    33.571609
# 44999         -0.522740             -51.724408   -41.855848
#
#        previous_loan_defaults_on_file
# 0                         -105.868637
# 1                          947.746253
# 2                         -105.868637
# 3                         -105.868637
# 4                         -105.868637
# ...                               ...
# 44995                     -105.868637
# 44996                     -105.868637
# 44997                     -105.868637
# 44998                     -105.868637
# 44999                     -105.868637
#
# [45000 rows x 4 columns]

# %%
dataToAnalyze.to_csv('Internal_test_0_datasetForMultivariateVSExceptIV.csv')

# %%
results.to_csv('Internal_test_0_multivariateVS_woe_mappings_iv.csv')
